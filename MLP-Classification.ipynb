# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
from skimage import color
# from sklearn.metrics import confusion_matrix
from sklearn import metrics
import seaborn as sns

# %% [markdown]
# ### Loading datas

# %%
# loading datas
from keras.datasets import cifar10
(x_train,y_train) , (x_test,y_test) = cifar10.load_data()
reshaped_all_datas = np.concatenate((x_train,x_test))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step
# 170508288/170498071 [==============================] - 3s 0us/step

# %% [markdown]
# ### Plotting 10 random images

# %%
#plotting 10 random images from batch1
randomlist = random.sample(range(0, len(reshaped_all_datas)), 10)

for i in range(10):
    plt.subplot(4,4,i+1)
    plt.imshow(reshaped_all_datas[randomlist[i]])
plt.show()

# %% [markdown]
# We have three types of datas: <br>
# 1- training <br>
# 2- validation <br>
# 3- test <br> <br>
#
# Also we have three types of training datas <br>
# 1- Batch based : All data pints are applied, simultaneously <br>
# 2- Stochastic based: Data are shuffled and then data points are applied one by one <br>
# 3- Stochastic mini batch based: training data set are randomly divided to a certain number of subsets (minbatches); then at each time a min-batch is chosen and applied <br><br>

# %% [markdown]
# ### Pre Processing

# %%
#converting RGB to Grayscale (takes too much time)
def rgb2gray(rgb):
    r, g, b = rgb[:,:,0], rgb[:,:,1], rgb[:,:,2]
    gray = 0.2989 * r + 0.5870 * g + 0.1140 * b
    return gray

temp = []
for i in range(len(reshaped_all_datas)):
    img = reshaped_all_datas[i]
    ig = rgb2gray(img)
    ig = ig.reshape(1,32,32)
    temp.extend(ig.tolist())
reshaped_all_datas = np.array(temp)

# %%
#finding max and min in all datas
all_data_max = np.amax(reshaped_all_datas)
all_data_min = np.amin(reshaped_all_datas)
#normalizing datas
normalized_all_datas = reshaped_all_datas.astype('float32')/(all_data_max - all_data_min)

# %% [markdown]
# ### MLP

# %% [markdown]
# ##### Creating Dataset

# %%
Y = np.concatenate((y_train,y_test)) #target
X = normalized_all_datas #input
(x_train,x_valid,x_test) = X[:40000],X[40000:50000],X[50000:]
(y_train,y_valid,y_test) = Y[:40000],Y[40000:50000],Y[50000:]

#uncomment if rgb to grayscale used
x_train = x_train.reshape(x_train.shape[0],32,32,1)
x_valid = x_valid.reshape(x_valid.shape[0],32,32,1)
x_test = x_test.reshape(x_test.shape[0],32,32,1)

y_train = tf.keras.utils.to_categorical(y_train,10)
y_valid = tf.keras.utils.to_categorical(y_valid,10)
y_test = tf.keras.utils.to_categorical(y_test,10)

# %% [markdown]
# #### Creating Model

# %%
from keras import layers
model = tf.keras.Sequential()

activation_func = 'relu'
# activation_func = tf.keras.activations.tanh
# activation_func = tf.keras.activations.sigmoid
# activation_func = tf.keras.activations.softmax

#CNN
# model.add(layers.Conv2D(filters=35, kernel_size=2, padding='same', activation=activation_func, input_shape=(32,32,1))) 
# model.add(layers.MaxPooling2D(pool_size=2))
# model.add(layers.Dropout(0.2))
# model.add(layers.Conv2D(filters=50, kernel_size=2, padding='same', activation=activation_func))
# model.add(layers.MaxPooling2D(pool_size=2))
# model.add(layers.Dropout(0.2))
# model.add(layers.Flatten())


model.add(layers.Flatten(input_shape = (32, 32, 1)))
model.add(layers.Dense(500, activation=activation_func))
model.add(layers.Dropout(0.3))

model.add(layers.Dense(400, activation=activation_func))
model.add(layers.Dropout(0.3))

# model.add(layers.Dense(150, activation=activation_func))
# model.add(layers.Dropout(0.3))

# model.add(layers.Dense(150, activation=activation_func))
# model.add(layers.Dropout(0.4))

# model.add(layers.Dense(150, activation=activation_func))
# model.add(layers.Dropout(0.3))

#last layer
model.add(layers.Dense(10, activation='softmax'))

# %% [markdown]
# #### Compiling the Model

# %%
loss_func = 'categorical_crossentropy'
# loss_func = 'mean_squared_error'
# loss_func = 'mean_absolute_error'

optimizer_func = 'adam'
# optimizer_func = tf.keras.optimizers.SGD(learning_rate = 0.1)
# optimizer_func = tf.keras.optimizers.Adagrad(learning_rate = 0.1)

model.compile(loss=loss_func,
              optimizer=optimizer_func,
              metrics=['accuracy'])

# %% [markdown]
# #### Training Model

# %%
import datetime
start = datetime.datetime.now()
trainedModel = model.fit(x_train, y_train, batch_size=512, epochs=50, validation_data = (x_valid,y_valid))
end = datetime.datetime.now()
# Out:
# Epoch 1/50
# 79/79 [==============================] - 1s 8ms/step - loss: 2.1531 - accuracy: 0.2096 - val_loss: 2.0135 - val_accuracy: 0.2694
# Epoch 2/50
# 79/79 [==============================] - 0s 5ms/step - loss: 2.0201 - accuracy: 0.2687 - val_loss: 1.9725 - val_accuracy: 0.2874
# Epoch 3/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9652 - accuracy: 0.2903 - val_loss: 1.8949 - val_accuracy: 0.3206
# Epoch 4/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9231 - accuracy: 0.3094 - val_loss: 1.8564 - val_accuracy: 0.3363
# Epoch 5/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.9008 - accuracy: 0.3214 - val_loss: 1.8406 - val_accuracy: 0.3336
# Epoch 6/50
# 79/79 [==============================] - 1s 6ms/step - loss: 1.8834 - accuracy: 0.3286 - val_loss: 1.8266 - val_accuracy: 0.3532
# Epoch 7/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8665 - accuracy: 0.3333 - val_loss: 1.8053 - val_accuracy: 0.3561
# Epoch 8/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8474 - accuracy: 0.3374 - val_loss: 1.7920 - val_accuracy: 0.3661
# Epoch 9/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8331 - accuracy: 0.3448 - val_loss: 1.7698 - val_accuracy: 0.3666
# Epoch 10/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8214 - accuracy: 0.3486 - val_loss: 1.7852 - val_accuracy: 0.3645
# Epoch 11/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.8109 - accuracy: 0.3532 - val_loss: 1.7440 - val_accuracy: 0.3810
# Epoch 12/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7929 - accuracy: 0.3584 - val_loss: 1.7482 - val_accuracy: 0.3785
# Epoch 13/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7892 - accuracy: 0.3600 - val_loss: 1.7425 - val_accuracy: 0.3800
# Epoch 14/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7823 - accuracy: 0.3627 - val_loss: 1.7474 - val_accuracy: 0.3732
# Epoch 15/50
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7632 - accuracy: 0.3690 - val_loss: 1.7179 - val_accuracy: 0.3838
# Epoch 16/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7494 - accuracy: 0.3778 - val_loss: 1.7057 - val_accuracy: 0.3906
# Epoch 17/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7422 - accuracy: 0.3758 - val_loss: 1.6939 - val_accuracy: 0.3995
# Epoch 18/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7363 - accuracy: 0.3772 - val_loss: 1.6959 - val_accuracy: 0.3999
# Epoch 19/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7218 - accuracy: 0.3873 - val_loss: 1.6841 - val_accuracy: 0.4055
# Epoch 20/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7193 - accuracy: 0.3836 - val_loss: 1.6954 - val_accuracy: 0.3995
# Epoch 21/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7125 - accuracy: 0.3881 - val_loss: 1.6835 - val_accuracy: 0.4030
# Epoch 22/50
# 79/79 [==============================] - 0s 6ms/step - loss: 1.7093 - accuracy: 0.3895 - val_loss: 1.7010 - val_accuracy: 0.3935
# Epoch 23/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7096 - accuracy: 0.3884 - val_loss: 1.6943 - val_accuracy: 0.4011
# Epoch 24/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.7021 - accuracy: 0.3919 - val_loss: 1.6965 - val_accuracy: 0.3951
# Epoch 25/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6974 - accuracy: 0.3943 - val_loss: 1.6709 - val_accuracy: 0.4093
# Epoch 26/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6828 - accuracy: 0.4000 - val_loss: 1.6650 - val_accuracy: 0.4105
# Epoch 27/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6809 - accuracy: 0.3977 - val_loss: 1.6911 - val_accuracy: 0.3934
# Epoch 28/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6684 - accuracy: 0.4054 - val_loss: 1.6375 - val_accuracy: 0.4257
# Epoch 29/50
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6667 - accuracy: 0.4016 - val_loss: 1.6641 - val_accuracy: 0.4130
# Epoch 30/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6710 - accuracy: 0.4016 - val_loss: 1.6511 - val_accuracy: 0.4177
# Epoch 31/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6677 - accuracy: 0.4037 - val_loss: 1.6583 - val_accuracy: 0.4131
# Epoch 32/50
# 79/79 [==============================] - 1s 6ms/step - loss: 1.6603 - accuracy: 0.4058 - val_loss: 1.6448 - val_accuracy: 0.4181
# Epoch 33/50
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6537 - accuracy: 0.4070 - val_loss: 1.6546 - val_accuracy: 0.4169
# Epoch 34/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6444 - accuracy: 0.4100 - val_loss: 1.6694 - val_accuracy: 0.4117
# Epoch 35/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6461 - accuracy: 0.4105 - val_loss: 1.6277 - val_accuracy: 0.4246
# Epoch 36/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6326 - accuracy: 0.4159 - val_loss: 1.6288 - val_accuracy: 0.4246
# Epoch 37/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6397 - accuracy: 0.4147 - val_loss: 1.6574 - val_accuracy: 0.4113
# Epoch 38/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6246 - accuracy: 0.4202 - val_loss: 1.6257 - val_accuracy: 0.4282
# Epoch 39/50
# 79/79 [==============================] - 0s 6ms/step - loss: 1.6259 - accuracy: 0.4196 - val_loss: 1.6311 - val_accuracy: 0.4237
# Epoch 40/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6256 - accuracy: 0.4155 - val_loss: 1.6432 - val_accuracy: 0.4153
# Epoch 41/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6258 - accuracy: 0.4173 - val_loss: 1.6244 - val_accuracy: 0.4264
# Epoch 42/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6213 - accuracy: 0.4206 - val_loss: 1.6313 - val_accuracy: 0.4217
# Epoch 43/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6156 - accuracy: 0.4212 - val_loss: 1.6255 - val_accuracy: 0.4236
# Epoch 44/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6136 - accuracy: 0.4221 - val_loss: 1.6328 - val_accuracy: 0.4192
# Epoch 45/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6125 - accuracy: 0.4223 - val_loss: 1.6174 - val_accuracy: 0.4299
# Epoch 46/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.6004 - accuracy: 0.4286 - val_loss: 1.6255 - val_accuracy: 0.4267
# Epoch 47/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.5954 - accuracy: 0.4307 - val_loss: 1.6417 - val_accuracy: 0.4176
# Epoch 48/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.5939 - accuracy: 0.4284 - val_loss: 1.6097 - val_accuracy: 0.4356
# Epoch 49/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.5970 - accuracy: 0.4300 - val_loss: 1.6237 - val_accuracy: 0.4231
# Epoch 50/50
# 79/79 [==============================] - 0s 5ms/step - loss: 1.5973 - accuracy: 0.4276 - val_loss: 1.6271 - val_accuracy: 0.4236

# %%
print('Training Duration: ', end-start)
# Out:
# Training Duration:  0:00:22.232441

# %% [markdown]
# #### Evaluating the Model

# %%
history = trainedModel.history
loss = history['loss']
val_loss = history['val_loss']
acc = history['accuracy']
val_acc = history['val_accuracy']

plt.xlabel('Epochs')
plt.ylabel('loss')
plt.plot(loss)
plt.plot(val_loss)
plt.legend(['loss','val_loss'])
plt.figure()
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.plot(acc)
plt.plot(val_acc)
plt.legend(['acc','val_acc'])

# %%
test_loss,test_accuracy = model.evaluate(x_test, y_test)
print(test_loss)
print(test_accuracy)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.6305 - accuracy: 0.4170
# 1.630496859550476
# 0.4169999957084656

# %%
#confusion matrix
y_pred = model.predict(x_test)
y_pred_temp = []

for i in range(len(y_pred)):
  pred_index = np.argmax(y_pred[i])
  y_pred_temp.append(pred_index)
y_test_temp = []
for i in range(len(y_test)):
  test_index = np.argmax(y_test[i])
  y_test_temp.append(test_index)

matrix_confusion = metrics.confusion_matrix(y_test_temp, y_pred_temp)
mc = sns.heatmap(matrix_confusion, square=True, annot=True, cmap='Blues', fmt='d', cbar=False)
mc.set_title('Confusion Matrix\n');
mc.set_xlabel('\nPredicted Values')
mc.set_ylabel('Actual Values ');
plt.show()
#calculating other metrics
print(metrics.classification_report(y_test_temp, y_pred_temp, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.489     0.315     0.383      1000
#            1      0.557     0.506     0.530      1000
#            2      0.364     0.289     0.322      1000
#            3      0.324     0.166     0.220      1000
#            4      0.311     0.354     0.331      1000
#            5      0.405     0.396     0.400      1000
#            6      0.330     0.647     0.437      1000
#            7      0.457     0.504     0.480      1000
#            8      0.539     0.488     0.512      1000
#            9      0.476     0.505     0.490      1000
#
#     accuracy                          0.417     10000
#    macro avg      0.425     0.417     0.411     10000
# weighted avg      0.425     0.417     0.411     10000
